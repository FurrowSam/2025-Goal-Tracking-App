# %%
import pandas as pd
import streamlit as st
from datetime import date

# %%
progress_df = pd.read_csv("progress_tracker.csv")

# %%
progress_df
# Out:
#      Unnamed: 0 Morning Workout      Breakfast Job Search / Project Review  \
# 0    2025-01-01   Not Completed  Not Completed               Not Completed
# 1    2025-01-02   Not Completed  Not Completed               Not Completed
# 2    2025-01-03   Not Completed  Not Completed               Not Completed
# 3    2025-01-04   Not Completed  Not Completed               Not Completed
# 4    2025-01-05   Not Completed  Not Completed               Not Completed
# ..          ...             ...            ...                         ...
# 360  2025-12-27   Not Completed  Not Completed               Not Completed
# 361  2025-12-28   Not Completed  Not Completed               Not Completed
# 362  2025-12-29   Not Completed  Not Completed               Not Completed
# 363  2025-12-30   Not Completed  Not Completed               Not Completed
# 364  2025-12-31   Not Completed  Not Completed               Not Completed
#
#         Work Hours Afternoon Walk  Snack/Refresh AI/ML Projects / Job Search  \
# 0    Not Completed  Not Completed  Not Completed               Not Completed
# 1    Not Completed  Not Completed  Not Completed               Not Completed
# 2    Not Completed  Not Completed  Not Completed               Not Completed
# 3    Not Completed  Not Completed  Not Completed               Not Completed
# 4    Not Completed  Not Completed  Not Completed               Not Completed
# ..             ...            ...            ...                         ...
# 360  Not Completed  Not Completed  Not Completed               Not Completed
# 361  Not Completed  Not Completed  Not Completed               Not Completed
# 362  Not Completed  Not Completed  Not Completed               Not Completed
# 363  Not Completed  Not Completed  Not Completed               Not Completed
# 364  Not Completed  Not Completed  Not Completed               Not Completed
#
#     Afternoon Workout Dinner / Chores      Free Time Plan for Tomorrow
# 0       Not Completed   Not Completed  Not Completed     Not Completed
# 1       Not Completed   Not Completed  Not Completed     Not Completed
# 2       Not Completed   Not Completed  Not Completed     Not Completed
# 3       Not Completed   Not Completed  Not Completed     Not Completed
# 4       Not Completed   Not Completed  Not Completed     Not Completed
# ..                ...             ...            ...               ...
# 360     Not Completed   Not Completed  Not Completed     Not Completed
# 361     Not Completed   Not Completed  Not Completed     Not Completed
# 362     Not Completed   Not Completed  Not Completed     Not Completed
# 363     Not Completed   Not Completed  Not Completed     Not Completed
# 364     Not Completed   Not Completed  Not Completed     Not Completed
#
# [365 rows x 12 columns]

# %%
# Create a date range for the year
date_range = pd.date_range(start="2025-01-01", end="2025-12-31", freq="D")

# %%
# Initialize DataFrame with all activities as columns
progress_table = pd.DataFrame(index=date_range, columns=activities)

# %%
# Fill the table with placeholders (e.g., "Not Completed")
progress_table[:] = "Not Completed"

# %%
# Save to a CSV file for tracking
progress_table.to_csv("progress_tracker.csv")

# %%
print("Progress table created! Here's a preview:")
print(progress_table.head())

# %%
# Load the table
progress_table = pd.read_csv("progress_tracker.csv", index_col=0)

# %%
progress_table

# %%
progress_table.info()

# %%
# Initialize the DataFrame or load from a CSV file

def load_data():
    # Define activities
    activities = [
        "Workout Session 1",
        "Breakfast/Prep",
        "Job Search/Project Review",
        "Work Hours",
        "Afternoon Walk",
        "Snack/Refresh",
        "AI/ML Projects & Job Search",
        "Workout Session 2",
        "Dinner/Relaxation",
        "Free Time",
        "Plan for Tomorrow"
    ]
    # Create a date range for the year
    date_range = pd.date_range(start="2025-01-01", end="2025-12-31", freq="D")
    # Create DataFrame
    progress_table = pd.DataFrame(index=date_range, columns=activities)
    progress_table[:] = "Not Completed"  # Default status
    return progress_table

# Load data
progress_table = load_data()

# Title
st.title("Daily Progress Tracker")

# Select today's date
today = st.date_input("Select the date", date.today())

# Display activities for today
st.header(f"Activities for {today}")
if str(today) in progress_table.index:
    for activity in progress_table.columns:
        # Add a checkbox for each activity
        if st.checkbox(activity, key=f"{today}_{activity}"):
            progress_table.loc[str(today), activity] = "Completed"
        else:
            progress_table.loc[str(today), activity] = "Not Completed"

# Save progress
if st.button("Save Progress"):
    progress_table.to_csv("progress_tracker.csv")
    st.success("Progress saved!")

# Display the full table (optional)
if st.checkbox("Show Full Progress Table"):
    st.dataframe(progress_table)

# %%
streamlit run progress_tracker.py
